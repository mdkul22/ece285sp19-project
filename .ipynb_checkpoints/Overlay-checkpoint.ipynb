# %%
# %matplotlib notebook

import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as td
import torchvision as tv
from PIL import Image
import matplotlib.pyplot as plt
import nntools as nt
import math

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
# Out:
# cuda

# %%
dataset_root_dir="/datasets/ee285f-public/PascalVOC2012/JPEGImages/"

# %%
class ImgDataset(td.Dataset):
    def __init__(self, root_dir):
        super(ImgDataset,self).__init__()
        self.images_dir=root_dir
        self.files=os.listdir(self.images_dir)
        
    def __len__(self):
        return len(self.files)
    
    def __repr__(self):
        pass
    def __getitem__(self,idx):
        img_path=os.path.join(self.images_dir,self.files[idx])
        img=Image.open(img_path).convert('RGB')
        transform=tv.transforms.Compose([tv.transforms.Resize((228,228)),tv.transforms.ToTensor(),tv.transforms.Normalize([0.5]*3,[0.5]*3)])
        x=transform(img)
        return x

# %%
train_set=ImgDataset(dataset_root_dir)

# %%
def myimshow(image, ax=plt):
    image = image.to('cpu').detach().numpy()
    image = np.moveaxis(image, [0, 1, 2], [2, 0, 1])
    image = (image + 1) / 2
    image[image < 0] = 0
    image[image > 1] = 1
    h = ax.imshow(image)
    ax.axis('off')
    return h

# %%
fig1,(ax1,ax2)=plt.subplots(ncols=2)
myimshow(train_set[10],ax1)
myimshow(train_set[12],ax2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
class NNClassifier(nt.NeuralNetwork):

    def __init__(self):
        super(NNClassifier, self).__init__()
        self.cross_entropy = nn.CrossEntropyLoss()

    def criterion(self, y, d):
        return self.cross_entropy(y, d)

# %%
vgg = tv.models.vgg16_bn(pretrained=True)

# %%
a=[1,2,3,4]
print(a[:2])
# Out:
# [1, 2]

# %%
class VGG16Transfer(NNClassifier):

    def __init__(self, num_classes, fine_tuning=False):
        super(VGG16Transfer, self).__init__()
        vgg = tv.models.vgg16_bn(pretrained=True)
        for param in vgg.parameters():
            param.requires_grad = fine_tuning
        self.features = vgg.features[:43]
        self.feat_list=self.features
        self.features[43]=nn.Conv2d(512, 512, 3, padding=(1,1))
        self.temp1=self.features[43]
        self.features.append(nn.Conv2d(512,18,1))
        self.features.append(nn.Conv2d(512,36,1))
        self.classifier=vgg.classifier
        self.classifier[6]=nn.Linear(4096,21)
        self.classifier.append(nn.Linear(4096,84))
        

    def forward(self, x):
        f=self.feat_list(x)

        f1=self.features[43](f)
        f2=self.features[44](f)
        f3=self.features[45](f)
        
        #op=Give f to roi pooling layer
        y1=self.classifier[:6](op)
        y2=self.classifier[6](y1)
        y3=self.classifier[7](y1)
        return y2,y3
